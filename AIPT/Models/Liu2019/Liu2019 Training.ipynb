# %% [markdown]
# ## Regressors

# %%
import torch
import pandas as pd
import numpy as np

from Liu2019_data_loader import train_test_loader, encode_data
from CNNx1_regressor import CNN_regressor
from DNN_regressor import DNN_regressor
from CNNx2_regressor import CNNx2_regressor

# %%
## load data
traindat = pd.read_csv('../Benchmarks/Liu2019_enrichment/cdr3s.table_Feb10.csv')
# exclude not_determined
dat = traindat.loc[traindat['enriched'] != 'not_determined']
x = dat['cdr3'].values
y_reg = dat['log10(R3/R2)'].values
# scale y_reg
y_reg_mean = np.mean(y_reg)
y_reg_std = np.std(y_reg)
y_reg_new = (y_reg - y_reg_mean) / y_reg_std

# %%
X_dat = np.array([encode_data(item, gapped = True, seq_len = 18) for item in x])
train_loader, test_loader = train_test_loader(X_dat, np.array(y_reg_new), batch_size=100)

# %%
X_dat.shape, y_reg_mean, y_reg_std
# Out:
# ((54402, 18, 21), -0.6794162469900554, 0.6218747369373429)

# %% [markdown]
# ### 1 DNN models

# %%
model_names = ['Seq_32_32_reg']
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict = {'seq_len':18,
             'batch_size':100,
              'model_name':'Seq_32_32_reg',
              'epoch':70,
              'learning_rate':0.01,
              'fc_hidden_dim':32,
              'dropout_rate':0.3}

# %%
for i in range(len(model_names)):
    params = para_dict_DNN
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = DNN_regressor(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        r2, mse = model.evaluate(output, labels)
        train_r2_store.append(r2)
        train_mse_store.append(mse)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        r2, mse = model.evaluate(output, labels)
        test_r2_store.append(r2)
        test_mse_store.append(mse)

# %%
output = model.predict(test_loader)
labels = np.concatenate([i for _, i in test_loader])
r2 = model.evaluate(output, labels)

# %%
model

# %% [markdown]
# ### 3 CNN models

# %%
model_names = ['Seq_32x1_16', 'Seq_64x1_16_reg', 'Seq_32x1_16_filt3_reg']
n_filters = [32, 64, 32]
filter_sizes = [5,5,3]
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict_CNN = {'batch_size':100,
             'seq_len':18,
             'epoch':70,
             'learning_rate':0.01,
             'step_size':20,
             'n_filter':32,
             'filter_size':5,
             'fc_hidden_dim':16,
             'stride':2,
             'dropout_rate': 0.3}

# %%
train_r2_store = []
test_mse_store = []
train_mse_store = []
test_r2_store = []

for i in range(len(model_names)):
    params = para_dict_CNN
    params['n_filter'] = n_filters[i]
    params['filter_size'] = filter_sizes[i]
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = CNN_regressor(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        r2, mse = model.evaluate(output, labels)
        train_r2_store.append(r2)
        train_mse_store.append(mse)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        r2, mse = model.evaluate(output, labels)
        test_r2_store.append(r2)
        test_mse_store.append(mse)
# Out:
# ----------------------------
# start training model Seq_32x1_16-0.005
# -- Train set results --
# R2 score = 0.543
# MSE = 0.460
# -- Test set results --
# R2 score = 0.497
# MSE = 0.490
# ----------------------------
# start training model Seq_32x1_16-0.0005
# Epoch: 10: Loss=226.463
# R2 score = 0.484
# MSE = 0.520
# Epoch: 20: Loss=215.932
# R2 score = 0.507
# MSE = 0.496
# Epoch: 30: Loss=209.950
# R2 score = 0.521
# MSE = 0.482
# Epoch: 40: Loss=206.382
# R2 score = 0.529
# MSE = 0.474
# Epoch: 50: Loss=203.412
# R2 score = 0.536
# MSE = 0.467
# Epoch: 60: Loss=201.464
# R2 score = 0.540
# MSE = 0.463
# Epoch: 70: Loss=199.618
# R2 score = 0.545
# MSE = 0.458
# -- Train set results --
# R2 score = 0.545
# MSE = 0.458
# -- Test set results --
# R2 score = 0.485
# MSE = 0.502
# ----------------------------
# start training model Seq_32x1_16-0.001
# Epoch: 10: Loss=225.806
# R2 score = 0.485
# MSE = 0.518
# Epoch: 20: Loss=215.717
# R2 score = 0.508
# MSE = 0.495
# Epoch: 30: Loss=209.992
# R2 score = 0.521
# MSE = 0.482
# Epoch: 40: Loss=204.760
# R2 score = 0.533
# MSE = 0.470
# Epoch: 50: Loss=201.349
# R2 score = 0.541
# MSE = 0.462
# Epoch: 60: Loss=199.988
# R2 score = 0.544
# MSE = 0.459
# Epoch: 70: Loss=198.598
# R2 score = 0.547
# MSE = 0.456
# -- Train set results --
# R2 score = 0.549
# MSE = 0.454
# -- Test set results --
# R2 score = 0.494
# MSE = 0.493
# ----------------------------
# start training model Seq_32x1_16-5e-05
# Epoch: 10: Loss=293.730
# R2 score = 0.330
# MSE = 0.674
# Epoch: 20: Loss=257.094
# R2 score = 0.414
# MSE = 0.590
# Epoch: 30: Loss=244.187
# R2 score = 0.443
# MSE = 0.560
# Epoch: 40: Loss=237.336
# R2 score = 0.459
# MSE = 0.545
# Epoch: 50: Loss=233.124
# R2 score = 0.468
# MSE = 0.535
# Epoch: 60: Loss=230.779
# R2 score = 0.474
# MSE = 0.530
# Epoch: 70: Loss=228.230
# R2 score = 0.479
# MSE = 0.524
# -- Train set results --
# R2 score = 0.479
# MSE = 0.524
# -- Test set results --
# R2 score = 0.455
# MSE = 0.531
# ----------------------------
# start training model Seq_32x1_16-0.0001
# Epoch: 10: Loss=258.266
# R2 score = 0.411
# MSE = 0.593
# Epoch: 20: Loss=237.708
# R2 score = 0.458
# MSE = 0.546
# Epoch: 30: Loss=231.238
# R2 score = 0.473
# MSE = 0.531
# Epoch: 40: Loss=228.033
# R2 score = 0.480
# MSE = 0.523
# Epoch: 50: Loss=225.067
# R2 score = 0.487
# MSE = 0.517
# Epoch: 60: Loss=222.750
# R2 score = 0.492
# MSE = 0.511
# Epoch: 70: Loss=220.546
# R2 score = 0.497
# MSE = 0.506
# -- Train set results --
# R2 score = 0.497
# MSE = 0.506
# -- Test set results --
# R2 score = 0.464
# MSE = 0.522
# ----------------------------
# start training model Seq_64x1_16_reg-0.005
# Epoch: 10: Loss=209.352
# R2 score = 0.523
# MSE = 0.481
# Epoch: 20: Loss=201.895
# R2 score = 0.540
# MSE = 0.463
# Epoch: 30: Loss=197.489
# R2 score = 0.550
# MSE = 0.453
# Epoch: 40: Loss=193.280
# R2 score = 0.559
# MSE = 0.444
# Epoch: 50: Loss=191.338
# R2 score = 0.564
# MSE = 0.439
# Epoch: 60: Loss=190.650
# R2 score = 0.565
# MSE = 0.438
# Epoch: 70: Loss=188.329
# R2 score = 0.571
# MSE = 0.432
# -- Train set results --
# R2 score = 0.564
# MSE = 0.438
# -- Test set results --
# R2 score = 0.489
# MSE = 0.497
# ----------------------------
# start training model Seq_64x1_16_reg-0.0005
# Epoch: 10: Loss=217.762
# R2 score = 0.503
# MSE = 0.500
# Epoch: 20: Loss=204.715
# R2 score = 0.533
# MSE = 0.470
# Epoch: 30: Loss=200.212
# R2 score = 0.543
# MSE = 0.459
# Epoch: 40: Loss=196.013
# R2 score = 0.553
# MSE = 0.450
# Epoch: 50: Loss=192.677
# R2 score = 0.561
# MSE = 0.442
# Epoch: 60: Loss=189.827
# R2 score = 0.567
# MSE = 0.436
# Epoch: 70: Loss=188.015
# R2 score = 0.571
# MSE = 0.432
# -- Train set results --
# R2 score = 0.576
# MSE = 0.427
# -- Test set results --
# R2 score = 0.485
# MSE = 0.501
# ----------------------------
# start training model Seq_64x1_16_reg-0.001
# Epoch: 10: Loss=213.251
# R2 score = 0.514
# MSE = 0.490
# Epoch: 20: Loss=202.369
# R2 score = 0.538
# MSE = 0.465
# Epoch: 30: Loss=196.664
# R2 score = 0.551
# MSE = 0.451
# Epoch: 40: Loss=193.121
# R2 score = 0.560
# MSE = 0.443
# Epoch: 50: Loss=190.604
# R2 score = 0.565
# MSE = 0.438
# Epoch: 60: Loss=186.133
# R2 score = 0.575
# MSE = 0.427
# Epoch: 70: Loss=185.251
# R2 score = 0.577
# MSE = 0.425
# -- Train set results --
# R2 score = 0.581
# MSE = 0.422
# -- Test set results --
# R2 score = 0.491
# MSE = 0.496
# ----------------------------
# start training model Seq_64x1_16_reg-5e-05
# Epoch: 10: Loss=298.313
# R2 score = 0.320
# MSE = 0.685
# Epoch: 20: Loss=278.363
# R2 score = 0.365
# MSE = 0.639
# Epoch: 30: Loss=265.979
# R2 score = 0.393
# MSE = 0.611
# Epoch: 40: Loss=258.970
# R2 score = 0.410
# MSE = 0.594
# Epoch: 50: Loss=253.832
# R2 score = 0.421
# MSE = 0.582
# Epoch: 60: Loss=250.800
# R2 score = 0.428
# MSE = 0.576
# Epoch: 70: Loss=248.967
# R2 score = 0.432
# MSE = 0.572
# -- Train set results --
# R2 score = 0.432
# MSE = 0.572
# -- Test set results --
# R2 score = 0.391
# MSE = 0.593
# ----------------------------
# start training model Seq_64x1_16_reg-0.0001
# Epoch: 10: Loss=278.036
# R2 score = 0.366
# MSE = 0.638
# Epoch: 20: Loss=259.780
# R2 score = 0.408
# MSE = 0.596
# Epoch: 30: Loss=252.223
# R2 score = 0.425
# MSE = 0.579
# Epoch: 40: Loss=246.723
# R2 score = 0.437
# MSE = 0.566
# Epoch: 50: Loss=234.330
# R2 score = 0.465
# MSE = 0.538
# Epoch: 60: Loss=224.560
# R2 score = 0.488
# MSE = 0.515
# Epoch: 70: Loss=219.427
# R2 score = 0.500
# MSE = 0.504
# -- Train set results --
# R2 score = 0.503
# MSE = 0.501
# -- Test set results --
# R2 score = 0.461
# MSE = 0.525
# ----------------------------
# start training model Seq_32x1_16_filt3_reg-0.005
# Epoch: 10: Loss=215.809
# R2 score = 0.508
# MSE = 0.495
# Epoch: 20: Loss=210.591
# R2 score = 0.520
# MSE = 0.483
# Epoch: 30: Loss=207.526
# R2 score = 0.527
# MSE = 0.476
# Epoch: 40: Loss=206.268
# R2 score = 0.530
# MSE = 0.474
# Epoch: 50: Loss=205.573
# R2 score = 0.531
# MSE = 0.472
# Epoch: 60: Loss=204.181
# R2 score = 0.534
# MSE = 0.469
# Epoch: 70: Loss=202.385
# R2 score = 0.538
# MSE = 0.465
# -- Train set results --
# R2 score = 0.545
# MSE = 0.458
# -- Test set results --
# R2 score = 0.492
# MSE = 0.495
# ----------------------------
# start training model Seq_32x1_16_filt3_reg-0.0005
# Epoch: 10: Loss=235.720
# R2 score = 0.463
# MSE = 0.541
# Epoch: 20: Loss=230.580
# R2 score = 0.474
# MSE = 0.529
# Epoch: 30: Loss=227.600
# R2 score = 0.481
# MSE = 0.523
# Epoch: 40: Loss=224.847
# R2 score = 0.487
# MSE = 0.516
# Epoch: 50: Loss=222.496
# R2 score = 0.493
# MSE = 0.511
# Epoch: 60: Loss=220.775
# R2 score = 0.496
# MSE = 0.507
# Epoch: 70: Loss=217.917
# R2 score = 0.503
# MSE = 0.500
# -- Train set results --
# R2 score = 0.506
# MSE = 0.498
# -- Test set results --
# R2 score = 0.465
# MSE = 0.521
# ----------------------------
# start training model Seq_32x1_16_filt3_reg-0.001
# Epoch: 10: Loss=227.955
# R2 score = 0.480
# MSE = 0.523
# Epoch: 20: Loss=218.518
# R2 score = 0.502
# MSE = 0.502
# Epoch: 30: Loss=212.208
# R2 score = 0.516
# MSE = 0.487
# Epoch: 40: Loss=207.989
# R2 score = 0.526
# MSE = 0.477
# Epoch: 50: Loss=205.889
# R2 score = 0.530
# MSE = 0.473
# Epoch: 60: Loss=203.074
# R2 score = 0.537
# MSE = 0.466
# Epoch: 70: Loss=201.544
# R2 score = 0.540
# MSE = 0.463
# -- Train set results --
# R2 score = 0.542
# MSE = 0.461
# -- Test set results --
# R2 score = 0.488
# MSE = 0.498
# ----------------------------
# start training model Seq_32x1_16_filt3_reg-5e-05
# Epoch: 10: Loss=327.309
# R2 score = 0.254
# MSE = 0.751
# Epoch: 20: Loss=309.582
# R2 score = 0.294
# MSE = 0.710
# Epoch: 30: Loss=298.786
# R2 score = 0.319
# MSE = 0.686
# Epoch: 40: Loss=292.111
# R2 score = 0.334
# MSE = 0.670
# Epoch: 50: Loss=286.730
# R2 score = 0.346
# MSE = 0.658
# Epoch: 60: Loss=279.235
# R2 score = 0.364
# MSE = 0.641
# Epoch: 70: Loss=269.979
# R2 score = 0.384
# MSE = 0.620
# -- Train set results --
# R2 score = 0.386
# MSE = 0.618
# -- Test set results --
# R2 score = 0.353
# MSE = 0.630
# ----------------------------
# start training model Seq_32x1_16_filt3_reg-0.0001
# Epoch: 10: Loss=306.979
# R2 score = 0.300
# MSE = 0.704
# Epoch: 20: Loss=291.442
# R2 score = 0.336
# MSE = 0.669
# Epoch: 30: Loss=284.235
# R2 score = 0.352
# MSE = 0.652
# Epoch: 40: Loss=279.070
# R2 score = 0.364
# MSE = 0.641
# Epoch: 50: Loss=276.404
# R2 score = 0.370
# MSE = 0.634
# Epoch: 60: Loss=272.571
# R2 score = 0.379
# MSE = 0.625
# Epoch: 70: Loss=270.365
# R2 score = 0.384
# MSE = 0.620
# -- Train set results --
# R2 score = 0.383
# MSE = 0.621
# -- Test set results --
# R2 score = 0.350
# MSE = 0.633

# %%
import pandas as pd
from itertools import combinations, product
model_names = ['Seq_32x1_16', 'Seq_64x1_16_reg', 'Seq_32x1_16_filt3_reg']
comb_names = product(model_names, lrs)
names = ['-'.join([model_name,str(lr)]) for model_name, lr in comb_names]
result_df = pd.DataFrame({'model_name': names,
                          'train_r2': train_r2_store, 'train_mse': train_mse_store,
                          'test_r2': test_r2_store, 'test_mse': test_mse_store})
result_df.to_csv('regressor_log_CNN.csv', index=None)

# %% [markdown]
# ### 2 CNNx2 models

# %%
model_names = ['Seq_32x2_16_reg', 'Seq_embed_32x1_16_reg']
n_filter1s = [32, 8]
n_filter2s = [64, 32]
filter_size1s = [5,1]
filter_size2s = [5,5]
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict_CNNx2 = {'seq_len':18,
              'batch_size':100,
              'model_name':'Seq_32x2_16_reg',
              'epoch':70,
              'learning_rate':0.001,
              'step_size':5,
              'n_filter1':32,
              'n_filter2':64,
              'filter_size1':5,
              'filter_size2':5,
              'fc_hidden_dim':16,
              'dropout_rate':0.5,
              'stride':2}

# %%
train_r2_store = []
test_mse_store = []
train_mse_store = []
test_r2_store = []

for i in range(len(model_names)):
    params = para_dict_CNNx2
    params['n_filter1'] = n_filter1s[i]
    params['filter_size1'] = filter_size1s[i]
    params['n_filter2'] = n_filter2s[i]
    params['filter_size2'] = filter_size2s[i]
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = CNNx2_regressor(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        r2, mse = model.evaluate(output, labels)
        train_r2_store.append(r2)
        train_mse_store.append(mse)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        r2, mse = model.evaluate(output, labels)
        test_r2_store.append(r2)
        test_mse_store.append(mse)

model = CNNx2_regressor(para_dict)
model.fit(train_loader)
# Out:
# ----------------------------
# start training model Seq_32x2_16_reg-0.005
# Epoch: 10: Loss=240.349
# R2 score = 0.452
# MSE = 0.551
# Epoch: 20: Loss=219.929
# R2 score = 0.498
# MSE = 0.505

# %% [markdown]
# ## Classifiers

# %%
import torch
import pandas as pd
import numpy as np

from Liu2019_data_loader import train_test_loader, encode_data
from CNNx1_classifier import CNN_classifier
from DNN_classifier import DNN_classifier
from CNNx2_classifier import CNNx2_classfier

# %%
## load data
traindat = pd.read_csv('cdr3s.table 2.csv')
# exclude not_determined
dat = traindat.loc[traindat['enriched'] != 'not_determined']
x = dat['cdr3'].values
y_class = [int(xx == 'positive') for xx in dat['enriched'].values]

# %% [markdown]
# ### 1 DNN model

# %%
model_names = ['Seq_32_32_class']
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict = {'seq_len':18,
             'batch_size':100,
              'model_name':'Seq_32_32_class',
              'epoch':70,
              'learning_rate':0.01,
              'fc_hidden_dim':32,
              'dropout_rate':0.3}

# %%
train_acc_store = []
test_mcc_store = []
train_mcc_store = []
test_acc_store = []

for i in range(len(model_names)):
    params = para_dict_DNN
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = DNN_classifier(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        train_acc_store.append(acc)
        train_mcc_store.append(mcc)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        test_acc_store.append(acc)
        test_mcc_store.append(mcc)

# %% [markdown]
# ### 3 CNN models

# %%
model_names = ['Seq_32x1_16_class', 'Seq_64x1_16_class', 'Seq_32x1_16_filt3_class']
n_filters = [32, 64, 32]
filter_sizes = [5,5,3]
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict_CNN = {'batch_size':100,
             'seq_len':18,
             'epoch':70,
             'learning_rate':0.01,
             'step_size':20,
             'n_filter':32,
             'filter_size':5,
             'fc_hidden_dim':16,
             'stride':2,
             'dropout_rate': 0.3}

# %%
for i in range(len(model_names)):
    params = para_dict_CNN
    params['n_filter'] = n_filters[i]
    params['filter_size'] = filter_sizes[i]
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = CNN_classifier(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        train_acc_store.append(acc)
        train_mcc_store.append(mcc)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        test_acc_store.append(acc)
        test_mcc_store.append(mcc)
# Out:
# ----------------------------
# start training model Seq_32x1_16-0.005
# -- Train set results --
# R2 score = 0.543
# MSE = 0.460
# -- Test set results --
# R2 score = 0.497
# MSE = 0.490
# ----------------------------
# start training model Seq_32x1_16-0.0005
# Epoch: 10: Loss=226.463
# R2 score = 0.484
# MSE = 0.520
# Epoch: 20: Loss=215.932
# R2 score = 0.507
# MSE = 0.496
# Epoch: 30: Loss=209.950
# R2 score = 0.521
# MSE = 0.482
# Epoch: 40: Loss=206.382
# R2 score = 0.529
# MSE = 0.474
# Epoch: 50: Loss=203.412
# R2 score = 0.536
# MSE = 0.467
# Epoch: 60: Loss=201.464
# R2 score = 0.540
# MSE = 0.463
# Epoch: 70: Loss=199.618
# R2 score = 0.545
# MSE = 0.458
# -- Train set results --
# R2 score = 0.545
# MSE = 0.458
# -- Test set results --
# R2 score = 0.485
# MSE = 0.502
# ----------------------------
# start training model Seq_32x1_16-0.001
# Epoch: 10: Loss=225.806
# R2 score = 0.485
# MSE = 0.518
# Epoch: 20: Loss=215.717
# R2 score = 0.508
# MSE = 0.495
# Epoch: 30: Loss=209.992
# R2 score = 0.521
# MSE = 0.482
# Epoch: 40: Loss=204.760
# R2 score = 0.533
# MSE = 0.470
# Epoch: 50: Loss=201.349
# R2 score = 0.541
# MSE = 0.462
# Epoch: 60: Loss=199.988
# R2 score = 0.544
# MSE = 0.459
# Epoch: 70: Loss=198.598
# R2 score = 0.547
# MSE = 0.456
# -- Train set results --
# R2 score = 0.549
# MSE = 0.454
# -- Test set results --
# R2 score = 0.494
# MSE = 0.493
# ----------------------------
# start training model Seq_32x1_16-5e-05
# Epoch: 10: Loss=293.730
# R2 score = 0.330
# MSE = 0.674
# Epoch: 20: Loss=257.094
# R2 score = 0.414
# MSE = 0.590
# Epoch: 30: Loss=244.187
# R2 score = 0.443
# MSE = 0.560
# Epoch: 40: Loss=237.336
# R2 score = 0.459
# MSE = 0.545
# Epoch: 50: Loss=233.124
# R2 score = 0.468
# MSE = 0.535
# Epoch: 60: Loss=230.779
# R2 score = 0.474
# MSE = 0.530
# Epoch: 70: Loss=228.230
# R2 score = 0.479
# MSE = 0.524
# -- Train set results --
# R2 score = 0.479
# MSE = 0.524
# -- Test set results --
# R2 score = 0.455
# MSE = 0.531
# ----------------------------
# start training model Seq_32x1_16-0.0001
# Epoch: 10: Loss=258.266
# R2 score = 0.411
# MSE = 0.593
# Epoch: 20: Loss=237.708
# R2 score = 0.458
# MSE = 0.546
# Epoch: 30: Loss=231.238
# R2 score = 0.473
# MSE = 0.531
# Epoch: 40: Loss=228.033
# R2 score = 0.480
# MSE = 0.523
# Epoch: 50: Loss=225.067
# R2 score = 0.487
# MSE = 0.517
# Epoch: 60: Loss=222.750
# R2 score = 0.492
# MSE = 0.511

# %% [markdown]
# ### 2 CNNx2 models

# %%
model_names = ['Seq_32x2_16_class', 'Seq_embed_32x1_16_class']
n_filter1s = [32, 8]
n_filter2s = [64, 32]
filter_size1s = [5,1]
filter_size2s = [5,5]
lrs = [0.005, 0.0005, 0.001, 5e-5, 0.0001]
para_dict_CNNx2 = {'seq_len':18,
              'batch_size':100,
              'model_name':'Seq_32x2_16_reg',
              'epoch':70,
              'learning_rate':0.001,
              'step_size':5,
              'n_filter1':32,
              'n_filter2':64,
              'filter_size1':5,
              'filter_size2':5,
              'fc_hidden_dim':16,
              'dropout_rate':0.5,
              'stride':2}

for i in range(len(model_names)):
    params = para_dict_CNNx2
    params['n_filter1'] = n_filter1s[i]
    params['filter_size1'] = filter_size1s[i]
    params['n_filter2'] = n_filter2s[i]
    params['filter_size2'] = filter_size2s[i]
    for lr in lrs:
        params['learning_rate'] = lr
        params['model_name'] = '-'.join([model_names[i],str(lr)])
        print('----------------------------')
        print('start training model %s' % params['model_name'])
        model = CNNx2_regressor(params)
        model.fit(train_loader)
                                         
        print('-- Train set results --')
        output = model.predict(train_loader)
        labels = np.concatenate([i for _, i in train_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        train_acc_store.append(acc)
        train_mcc_store.append(mcc)
        print('-- Test set results --')
        output = model.predict(test_loader)
        labels = np.concatenate([i for _, i in test_loader])
        mat, acc, mcc = model.evaluate(output, labels)
        test_acc_store.append(acc)
        test_mcc_store.append(mcc)
